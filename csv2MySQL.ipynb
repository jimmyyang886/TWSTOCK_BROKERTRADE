# %%
# -*- coding: utf-8 -*-
import pandas as pd
from os import walk
import csv
import re
import sqlalchemy
from sqlalchemy import create_engine


engine = create_engine("mysql+pymysql://teb101Club:teb101Club@localhost/twstock??charset=utf8mb4", max_overflow=5)

#query = "select distinct date from broker_transaction;"
query = "select max(date) from broker_transaction;"
datelist=list(engine.execute(query))
print(datelist)
# Out:
# [(datetime.date(2020, 8, 24),)]

# %%
#dateisolist=[]


latestDate=datelist[0][0]

#latestDate=max(datelist)[0].isoformat()
# for _date in datelist:
#     dateisolist.append(_date[0].isoformat())
#     print(_date[0].isoformat())
print(latestDate)
# Out:
# 2020-08-24

# %%
from datetime import datetime

import os

mypath = "TWSE/"

#file_path_list = []



def sqlcol(dfparam):    
    dtypedict = {}
    for i,j in zip(dfparam.columns, dfparam.dtypes):
        if "object"  in str(j):
            dtypedict.update({i: sqlalchemy.types.NVARCHAR(length=4)})

        if "datetime" in str(j):
            dtypedict.update({i: sqlalchemy.types.DATE()})

        if "float" in str(j):
            dtypedict.update({i: sqlalchemy.types.Float(precision=2, asdecimal=True)})

        if "int" in str(j):
            dtypedict.update({i: sqlalchemy.types.INT()})

        if "int64" in str(j):
            dtypedict.update({i: sqlalchemy.types.BIGINT()})

    return dtypedict

engine = create_engine("mysql+pymysql://teb101Club:teb101Club@127.0.0.1:3306/twstock??charset=utf8mb4", max_overflow=5)

for _directory in os.listdir(mypath):
    #print(directory) 
    #print(datetime_object)
    if datetime.strptime(_directory, '%Y%m%d').date() > latestDate:
        for file in os.listdir(mypath+_directory):
            if 'csv' in file: 
                whole_data = []
                filepath=mypath+_directory+'/'+file
                with open(filepath, newline='',encoding="utf-8") as csvfile:
                    #print(f"load file: {file}")
                    rows = csv.reader(csvfile)                

                    data = []
                    for row in rows:
                        data.append(row[0:5])
                        data.append(row[6:11])
                    ticker = re.search(r"[\d]+",data[4][1]).group(0)
                    date = datetime.strptime(_directory, '%Y%m%d').date() 
                    for i in data:
                        i.append(date)
                        i.append(ticker)

                    whole_data.extend(data[13:])    


                column = ['sn', 'bID', 'price', 'buy','sell','Date','sID']
                df = pd.DataFrame(whole_data, columns = column)

                #print(df)
                #print(f"Current Total Data: {df.info()}")
                # df.info()

                # print(df[df["sn"].isna()])                    
                df['bID'] = df["bID"].apply(lambda x: x[:4])    



                df["sn"] = df[df["sn"] != '']
                df = df.dropna()

                List_df = df[['bID','sID','Date','sn', 'price', 'buy','sell']]
                List_df[["Date"]] = List_df[["Date"]].astype('datetime64[ns]')
                List_df[["sn"]] = List_df[["sn"]].astype('int')
                List_df[["buy"]] = List_df[["buy"]].astype('int')
                List_df[["sell"]] = List_df[["sell"]].astype('int')
                List_df[["price"]] = List_df[["price"]].astype('float') 
                #List_df.info()
                #print(List_df)

                outputdict = sqlcol(List_df)

                print('import mysql', date, ticker)

                List_df.to_sql('broker_transaction', engine, schema='twstock',if_exists='append',index= False, dtype=outputdict, chunksize = 1000)
# import mysql 2020-08-25 4106
# import mysql 2020-08-25 4108
# import mysql 2020-08-25 4119
# import mysql 2020-08-25 4133
# import mysql 2020-08-25 4137
# import mysql 2020-08-25 4141
# import mysql 2020-08-25 4142
# import mysql 2020-08-25 4144
# import mysql 2020-08-25 4148
# import mysql 2020-08-25 4155
# import mysql 2020-08-25 4164
# import mysql 2020-08-25 4190
# import mysql 2020-08-25 4306
# import mysql 2020-08-25 4414
# import mysql 2020-08-25 4426
# import mysql 2020-08-25 4438
# import mysql 2020-08-25 4439
# import mysql 2020-08-25 4526
# import mysql 2020-08-25 4532
# import mysql 2020-08-25 4536
# import mysql 2020-08-25 4540
# import mysql 2020-08-25 4545
# import mysql 2020-08-25 4551
# import mysql 2020-08-25 4552
# import mysql 2020-08-25 4555
# import mysql 2020-08-25 4557
# import mysql 2020-08-25 4560
# import mysql 2020-08-25 4562
# import mysql 2020-08-25 4564
# import mysql 2020-08-25 4566
# import mysql 2020-08-25 4571
# import mysql 2020-08-25 4572
# import mysql 2020-08-25 4576
# import mysql 2020-08-25 4581
# import mysql 2020-08-25 4720
# import mysql 2020-08-25 4722
# import mysql 2020-08-25 4725
# import mysql 2020-08-25 4737
# import mysql 2020-08-25 4739
# import mysql 2020-08-25 4746
# import mysql 2020-08-25 4755
# import mysql 2020-08-25 4763
# import mysql 2020-08-25 4764
# import mysql 2020-08-25 4766
# import mysql 2020-08-25 4807
# import mysql 2020-08-25 4904
# import mysql 2020-08-25 4906
# import mysql 2020-08-25 4912
# import mysql 2020-08-25 4915
# import mysql 2020-08-25 4916
# import mysql 2020-08-25 4919
# import mysql 2020-08-25 4927
# import mysql 2020-08-25 4930
# import mysql 2020-08-25 4934
# import mysql 2020-08-25 4935
# import mysql 2020-08-25 4938
# import mysql 2020-08-25 4942
# import mysql 2020-08-25 4943
# import mysql 2020-08-25 4952
# import mysql 2020-08-25 4956
# import mysql 2020-08-25 4958
# import mysql 2020-08-25 4960
# import mysql 2020-08-25 4961
# import mysql 2020-08-25 4967
# import mysql 2020-08-25 4968
# import mysql 2020-08-25 4976
# import mysql 2020-08-25 4977
# import mysql 2020-08-25 4989
# import mysql 2020-08-25 4994
# import mysql 2020-08-25 4999
# import mysql 2020-08-25 5007
# import mysql 2020-08-25 5203
# import mysql 2020-08-25 5215
# import mysql 2020-08-25 5225
# import mysql 2020-08-25 5234
# import mysql 2020-08-25 5243
# import mysql 2020-08-25 5258
# import mysql 2020-08-25 5264
# import mysql 2020-08-25 5269
# import mysql 2020-08-25 5283
# import mysql 2020-08-25 5284
# import mysql 2020-08-25 5285
# import mysql 2020-08-25 5288
# import mysql 2020-08-25 5305
# import mysql 2020-08-25 5388
# import mysql 2020-08-25 5434
# import mysql 2020-08-25 5469
# import mysql 2020-08-25 5471
# import mysql 2020-08-25 5484
# import mysql 2020-08-25 5515
# import mysql 2020-08-25 5519
# import mysql 2020-08-25 5521
# import mysql 2020-08-25 5522
# import mysql 2020-08-25 5525
# import mysql 2020-08-25 5531
# import mysql 2020-08-25 5533
# import mysql 2020-08-25 5534
# import mysql 2020-08-25 5538
# import mysql 2020-08-25 5546
# import mysql 2020-08-25 5607
# import mysql 2020-08-25 5608
# import mysql 2020-08-25 5706
# import mysql 2020-08-25 5871
# import mysql 2020-08-25 5876
# import mysql 2020-08-25 5880
# import mysql 2020-08-25 5906
# import mysql 2020-08-25 5907
# import mysql 2020-08-25 6005
# import mysql 2020-08-25 6024
# import mysql 2020-08-25 6108
# import mysql 2020-08-25 6112
# import mysql 2020-08-25 6115
# import mysql 2020-08-25 6116
# import mysql 2020-08-25 6117
# import mysql 2020-08-25 6120
# import mysql 2020-08-25 6128
# import mysql 2020-08-25 6131
# import mysql 2020-08-25 6133
# import mysql 2020-08-25 6136
# import mysql 2020-08-25 6139
# import mysql 2020-08-25 6141
# import mysql 2020-08-25 6142
# import mysql 2020-08-25 6152
# import mysql 2020-08-25 6153
# import mysql 2020-08-25 6155
# import mysql 2020-08-25 6164
# import mysql 2020-08-25 6165
# import mysql 2020-08-25 6166
# import mysql 2020-08-25 6168
# import mysql 2020-08-25 6172
# import mysql 2020-08-25 6176
# import mysql 2020-08-25 6177
# import mysql 2020-08-25 6183
# import mysql 2020-08-25 6184
# import mysql 2020-08-25 6189
# import mysql 2020-08-25 6191
# import mysql 2020-08-25 6192
# import mysql 2020-08-25 6196
# import mysql 2020-08-25 6197
# import mysql 2020-08-25 6201
# import mysql 2020-08-25 6202
# import mysql 2020-08-25 6205
# import mysql 2020-08-25 6206

# %%
_directory='20200820'
whole_data = []
filepath=mypath+_directory+'/'+'9958_2020-08-20.csv'
with open(filepath, newline='',encoding="utf-8") as csvfile:
    #print(f"load file: {file}")
    rows = csv.reader(csvfile)                

    data = []
    for row in rows:
        data.append(row[0:5])
        data.append(row[6:11])
    ticker = re.search(r"[\d]+",data[4][1]).group(0)
    date = datetime.strptime(_directory, '%Y%m%d').date() 
    for i in data:
        i.append(date)
        i.append(ticker)

    whole_data.extend(data[13:])    


column = ['sn', 'bID', 'price', 'buy','sell','Date','sID']
df = pd.DataFrame(whole_data, columns = column)

#print(df)
#print(f"Current Total Data: {df.info()}")
# df.info()

# print(df[df["sn"].isna()])                    
df['bID'] = df["bID"].apply(lambda x: x[:4])    



df["sn"] = df[df["sn"] != '']
df = df.dropna()

List_df = df[['bID','sID','Date','sn', 'price', 'buy','sell']]
List_df[["Date"]] = List_df[["Date"]].astype('datetime64[ns]')
List_df[["sn"]] = List_df[["sn"]].astype('int')
List_df[["buy"]] = List_df[["buy"]].astype('int')
List_df[["sell"]] = List_df[["sell"]].astype('int')
List_df[["price"]] = List_df[["price"]].astype('float') 
List_df
List_df.to_sql('broker_transaction', engine, schema='twstock',if_exists='append',index= False, dtype=outputdict, chunksize = 1000)
