# %%
# -*- coding: utf-8 -*-
import pandas as pd
from os import walk
import csv
import re
import sqlalchemy
from sqlalchemy import create_engine


engine = create_engine("mysql+pymysql://teb101Club:teb101Club@localhost/twstock??charset=utf8mb4", max_overflow=5)

query = "select distinct date from broker_transaction;"
datelist=list(engine.execute(query))

# %%
#dateisolist=[]


latestDate=max(datelist)[0]

#latestDate=max(datelist)[0].isoformat()
# for _date in datelist:
#     dateisolist.append(_date[0].isoformat())
#     print(_date[0].isoformat())
print(latestDate)
# Out:
# 2020-08-18

# %%
from datetime import datetime

import os

mypath = "TWSE/"

#file_path_list = []



def sqlcol(dfparam):    
    dtypedict = {}
    for i,j in zip(dfparam.columns, dfparam.dtypes):
        if "object"  in str(j):
            dtypedict.update({i: sqlalchemy.types.NVARCHAR(length=4)})

        if "datetime" in str(j):
            dtypedict.update({i: sqlalchemy.types.DATE()})

        if "float" in str(j):
            dtypedict.update({i: sqlalchemy.types.Float(precision=2, asdecimal=True)})

        if "int" in str(j):
            dtypedict.update({i: sqlalchemy.types.INT()})

        if "int64" in str(j):
            dtypedict.update({i: sqlalchemy.types.BIGINT()})

    return dtypedict

engine = create_engine("mysql+pymysql://teb101Club:teb101Club@127.0.0.1:3306/twstock??charset=utf8mb4", max_overflow=5)

for _directory in os.listdir(mypath):
    #print(directory) 
    #print(datetime_object)
    if datetime.strptime(_directory, '%Y%m%d').date() > latestDate:
        for file in os.listdir(mypath+_directory):
            if 'csv' in file: 
                whole_data = []
                filepath=mypath+_directory+'/'+file
                with open(filepath, newline='',encoding="utf-8") as csvfile:
                    #print(f"load file: {file}")
                    rows = csv.reader(csvfile)                

                    data = []
                    for row in rows:
                        data.append(row[0:5])
                        data.append(row[6:11])
                    ticker = re.search(r"[\d]+",data[4][1]).group(0)
                    date = datetime.strptime(_directory, '%Y%m%d').date() 
                    for i in data:
                        i.append(date)
                        i.append(ticker)

                    whole_data.extend(data[13:])    


            column = ['sn', 'bID', 'price', 'buy','sell','Date','sID']
            df = pd.DataFrame(whole_data, columns = column)

            #print(df)
            #print(f"Current Total Data: {df.info()}")
            # df.info()

            # print(df[df["sn"].isna()])                    
            df['bID'] = df["bID"].apply(lambda x: x[:4])    



            df["sn"] = df[df["sn"] != '']
            df = df.dropna()

            List_df = df[['bID','sID','Date','sn', 'price', 'buy','sell']]
            List_df[["Date"]] = List_df[["Date"]].astype('datetime64[ns]')
            List_df[["sn"]] = List_df[["sn"]].astype('int')
            List_df[["buy"]] = List_df[["buy"]].astype('int')
            List_df[["sell"]] = List_df[["sell"]].astype('int')
            List_df[["price"]] = List_df[["price"]].astype('float') 
            #List_df.info()
            #print(List_df)

            outputdict = sqlcol(List_df)
            
            print('import mysql', date, ticker)

            List_df.to_sql('broker_transaction', engine, schema='twstock',if_exists='append',index= False, dtype=outputdict, chunksize = 1000)
# Out:
# import mysql 2020-08-19 1101
# import mysql 2020-08-19 1102
# import mysql 2020-08-19 1103
# import mysql 2020-08-19 1104
# import mysql 2020-08-19 1108
# import mysql 2020-08-19 1109
# import mysql 2020-08-19 1110
# import mysql 2020-08-19 1201
# import mysql 2020-08-19 1203
# import mysql 2020-08-19 1210
# import mysql 2020-08-19 1213
# import mysql 2020-08-19 1215
# import mysql 2020-08-19 1216
# import mysql 2020-08-19 1217
# import mysql 2020-08-19 1218
# import mysql 2020-08-19 1219
# import mysql 2020-08-19 1220
# import mysql 2020-08-19 1225
# import mysql 2020-08-19 1227
# import mysql 2020-08-19 1229
# import mysql 2020-08-19 1231
# import mysql 2020-08-19 1232
# import mysql 2020-08-19 1233
# import mysql 2020-08-19 1234
# import mysql 2020-08-19 1235
# import mysql 2020-08-19 1236
# import mysql 2020-08-19 1256
# import mysql 2020-08-19 1301
# import mysql 2020-08-19 1303
# import mysql 2020-08-19 1304
# import mysql 2020-08-19 1305
# import mysql 2020-08-19 1307
# import mysql 2020-08-19 1308
# import mysql 2020-08-19 1309
# import mysql 2020-08-19 1310
# import mysql 2020-08-19 1312
# import mysql 2020-08-19 1313
# import mysql 2020-08-19 1314
# import mysql 2020-08-19 1315
# import mysql 2020-08-19 1316
# import mysql 2020-08-19 1319
# import mysql 2020-08-19 1321
# import mysql 2020-08-19 1323
# import mysql 2020-08-19 1324
# import mysql 2020-08-19 1325
# import mysql 2020-08-19 1326
# import mysql 2020-08-19 1337
# import mysql 2020-08-19 1338
# import mysql 2020-08-19 1339
# import mysql 2020-08-19 1340
# import mysql 2020-08-19 1341
# import mysql 2020-08-19 1402
# import mysql 2020-08-19 1409
# import mysql 2020-08-19 1410
# import mysql 2020-08-19 1413
# import mysql 2020-08-19 1414
# import mysql 2020-08-19 1416
# import mysql 2020-08-19 1417
# import mysql 2020-08-19 1418
# import mysql 2020-08-19 1419
# import mysql 2020-08-19 1423
# import mysql 2020-08-19 1432
# import mysql 2020-08-19 1434
# import mysql 2020-08-19 1435
# import mysql 2020-08-19 1436
# import mysql 2020-08-19 1437
# import mysql 2020-08-19 1438
# import mysql 2020-08-19 1439
# import mysql 2020-08-19 1440
# import mysql 2020-08-19 1441
# import mysql 2020-08-19 1442
# import mysql 2020-08-19 1443
# import mysql 2020-08-19 1444
# import mysql 2020-08-19 1445
# import mysql 2020-08-19 1446
# import mysql 2020-08-19 1447
# import mysql 2020-08-19 1449
# import mysql 2020-08-19 1451
# import mysql 2020-08-19 1452
# import mysql 2020-08-19 1453
# import mysql 2020-08-19 1454
# import mysql 2020-08-19 1455
# import mysql 2020-08-19 1456
# import mysql 2020-08-19 1457
# import mysql 2020-08-19 1459
# import mysql 2020-08-19 1460
# import mysql 2020-08-19 1463
# import mysql 2020-08-19 1464
# import mysql 2020-08-19 1465
# import mysql 2020-08-19 1466
# import mysql 2020-08-19 1467
# import mysql 2020-08-19 1468
# import mysql 2020-08-19 1470
# import mysql 2020-08-19 1471
# import mysql 2020-08-19 1472
# import mysql 2020-08-19 1473
# import mysql 2020-08-19 1474
# import mysql 2020-08-19 1475
# import mysql 2020-08-19 1476
# import mysql 2020-08-19 1477
# import mysql 2020-08-19 1503
# import mysql 2020-08-19 1504
# import mysql 2020-08-19 1506
# import mysql 2020-08-19 1507
# import mysql 2020-08-19 1512
# import mysql 2020-08-19 1513
# import mysql 2020-08-19 1514
# import mysql 2020-08-19 1515
# import mysql 2020-08-19 1516
# import mysql 2020-08-19 1517
# import mysql 2020-08-19 1519
# import mysql 2020-08-19 1521
# import mysql 2020-08-19 1522
# import mysql 2020-08-19 1524
# import mysql 2020-08-19 1525
# import mysql 2020-08-19 1526
# import mysql 2020-08-19 1527
# import mysql 2020-08-19 1528
# import mysql 2020-08-19 1529
# import mysql 2020-08-19 1530
# import mysql 2020-08-19 1531
# import mysql 2020-08-19 1532
# import mysql 2020-08-19 1533
# import mysql 2020-08-19 1535
# import mysql 2020-08-19 1536
# import mysql 2020-08-19 1537
# import mysql 2020-08-19 1538
# import mysql 2020-08-19 1539
# import mysql 2020-08-19 1540
# import mysql 2020-08-19 1541
# import mysql 2020-08-19 1558
# import mysql 2020-08-19 1560
# import mysql 2020-08-19 1568
# import mysql 2020-08-19 1582
# import mysql 2020-08-19 1583
# import mysql 2020-08-19 1587
# import mysql 2020-08-19 1589
# import mysql 2020-08-19 1590
# import mysql 2020-08-19 1592
# import mysql 2020-08-19 1598
# import mysql 2020-08-19 1603
# import mysql 2020-08-19 1604
# import mysql 2020-08-19 1605
# import mysql 2020-08-19 1608
# import mysql 2020-08-19 1609
# import mysql 2020-08-19 1611
# import mysql 2020-08-19 1612
# import mysql 2020-08-19 1614
# import mysql 2020-08-19 1615
# import mysql 2020-08-19 1616
# import mysql 2020-08-19 1617
# import mysql 2020-08-19 1618
# import mysql 2020-08-19 1626
# import mysql 2020-08-19 1701
# import mysql 2020-08-19 1702
# import mysql 2020-08-19 1707
# import mysql 2020-08-19 1708
# import mysql 2020-08-19 1709
# import mysql 2020-08-19 1710
# import mysql 2020-08-19 1711
# import mysql 2020-08-19 1712
# import mysql 2020-08-19 1713
# import mysql 2020-08-19 1714
# import mysql 2020-08-19 1717
# import mysql 2020-08-19 1718
# import mysql 2020-08-19 1720
# import mysql 2020-08-19 1721
# import mysql 2020-08-19 1722
# import mysql 2020-08-19 1723
# import mysql 2020-08-19 1724
# import mysql 2020-08-19 1725
# import mysql 2020-08-19 1726
# import mysql 2020-08-19 1727
# import mysql 2020-08-19 1730
# import mysql 2020-08-19 1731
# import mysql 2020-08-19 1732
