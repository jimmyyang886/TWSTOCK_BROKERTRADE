# %%
import os

def batch_rename(path):
    count = 0
    for fname in os.listdir(path):
        new_fname = str(count)
        print (os.path.join(path, fname))
        os.rename(os.path.join(path, fname), os.path.join(path, new_fname))
        count = count + 1 


dir_path='./TWSE/'

filelist = os.listdir(dir_path)

#print(filelist)

#os.chdir(dir_path)

os.chdir(dir_path)
for _file in filelist:
    
    if _file.find('-')<1:
     
        source=_file.replace('-','')

        dest=source[:4]+'-'+source[4:6]+'-'+source[6:8]

        print(source, dest)
        os.rename(source, dest)
# Out:
# 20200722 2020-07-22
# 20200723 2020-07-23
# 20200724 2020-07-24
# 20200727 2020-07-27
# 20200728 2020-07-28
# 20200729 2020-07-29
# 20200730 2020-07-30
# 20200731 2020-07-31
# 20200803 2020-08-03
# 20200804 2020-08-04
# 20200805 2020-08-05
# 20200806 2020-08-06
# 20200807 2020-08-07
# 20200810 2020-08-10
# 20200811 2020-08-11
# 20200812 2020-08-12
# 20200813 2020-08-13
# 20200814 2020-08-14
# 20200817 2020-08-17
# 20200818 2020-08-18
# 20200819 2020-08-19
# 20200820 2020-08-20
# 20200821 2020-08-21
# 20200824 2020-08-24
# 20200825 2020-08-25
# 20200826 2020-08-26
# 20200827 2020-08-27
# 20200828 2020-08-28
# 20200831 2020-08-31
# 20200901 2020-09-01
# 20200902 2020-09-02
# 20200903 2020-09-03
# 20200904 2020-09-04
# 20200907 2020-09-07
# 20200908 2020-09-08
# 20200909 2020-09-09
# 20200910 2020-09-10
# 20200911 2020-09-11
# 20200914 2020-09-14
# 20200915 2020-09-15
# 20200916 2020-09-16
# 20200917 2020-09-17
# 20200918 2020-09-18
# 20200921 2020-09-21
# 20200922 2020-09-22
# 20200923 2020-09-23
# 20200924 2020-09-24
# 20200925 2020-09-25
# 20200926 2020-09-26
# 20200928 2020-09-28
# 20200929 2020-09-29
